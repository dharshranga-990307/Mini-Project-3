# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df3=pd.read_excel('edited.xlsx')
df3
# Out:
#          city      ft         bt            oem transmission  \
# 0     Chennai  Petrol        SUV            Kia    Automatic
# 1     Chennai  Petrol   Minivans         Maruti       Manual
# 2     Chennai  Petrol        SUV         Nissan       Manual
# 3     Chennai  Petrol  Hatchback        Hyundai       Manual
# 4     Chennai  Petrol  Hatchback          Honda       Manual
# ...       ...     ...        ...            ...          ...
# 8356  Kolkata  Petrol  Hatchback         Maruti       Manual
# 8357  Kolkata  Petrol  Hatchback         Maruti       Manual
# 8358  Kolkata  Petrol      Sedan  Mercedes-Benz    Automatic
# 8359  Kolkata  Petrol  Hatchback         Maruti       Manual
# 8360  Kolkata  Diesel        SUV        Renault       Manual
#
#          Insurance Validity     Ownership   Color        km  \
# 0     Third Party insurance   First Owner   Black   20000.0
# 1             Comprehensive   First Owner    Grey   20687.0
# ...

# %%
cat_cols=df3.select_dtypes(include=['object']).columns
num_cols = df3.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['city', 'ft', 'bt', 'oem', 'transmission', 'Insurance Validity',
#        'Ownership', 'Color', 'model'],
#       dtype='object')
# Numerical Variables:
# ['km', 'modelYear', 'Engine Displacement', 'Mileage', 'price', 'Seating Capacity', 'Vehicle_Age']

# %%
df3['oem'].value_counts()
# Out:
# oem
# Maruti                2249
# Hyundai               1651
# Honda                  864
# Tata                   431
# Mahindra               376
# Toyota                 325
# Ford                   311
# Renault                311
# Volkswagen             294
# Mercedes-Benz          244
# BMW                    184
# Skoda                  160
# Kia                    158
# Audi                   156
# Jeep                   112
# MG                      90
# Nissan                  78
# Chevrolet               76
# Datsun                  74
# Land Rover              44
# Volvo                   41
# Jaguar                  35
# Fiat                    31
# Mitsubishi              14
# Mini                    12
# Citroen                  8
# Porsche                  6
# Isuzu                    5
# Mahindra Renault         5
# Lexus                    5
# Mahindra Ssangyong       4
# Hindustan Motors         4
# Opel                     3
# Name: count, dtype: int64

# %%
value_counts = df3['oem'].value_counts().sort_values(ascending=False)


top_10 = value_counts.head(10)


sns.barplot(x=top_10.values, y=top_10.index)
plt.title('Top 10 Categories by Original Equipment Manufacturer')
plt.xlabel('No of cars')
plt.ylabel('Original Equipment Manufacturer')
# Out:
# Text(0, 0.5, 'Original Equipment Manufacturer')

# %%
value_counts = df3['model'].value_counts().sort_values(ascending=False)


top_10 = value_counts.head(10)


sns.barplot(x=top_10.values, y=top_10.index)
plt.title('Top 10 Categories by Car Model')
plt.xlabel('No. of Cars Sold')
plt.ylabel('Car Model')
# Out:
# Text(0, 0.5, 'Car Model')

# %%
# Calculate value counts
value_counts = df3['transmission'].value_counts()

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)

# Add a white circle in the center to create the doughnut effect
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')
plt.title('Proportion of Body Type')
plt.show()

# %%
# Create a count plot
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='ft', data=df3)
plt.title('Count Plot of Fuel Type')
plt.xlabel('Fuel Type Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(13, 6))
# Calculate value counts
value_counts = df3['bt'].value_counts()

# Create a new DataFrame for plotting
plot_data = pd.DataFrame({'bt': value_counts.index, 'Values': value_counts.values})

# Violin Plot
sns.swarmplot(x='bt', y='Values', data=plot_data,size=6)
plt.title('Plot By Category of Body Type')
plt.xlabel('Body Type')
plt.ylabel('No. Of Cars Sold')
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Scatter Plot
sns.scatterplot(x='Mileage', y='Vehicle_Age', data=df3)
plt.title('Scatter Plot of Mileage vs. Vehicle_Age')
plt.xlabel('Mileage')
plt.ylabel('Age of Vehicle')
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Scatter Plot
sns.scatterplot(x='', y='Vehicle_Age', data=df3)
plt.title('Scatter Plot of Mileage vs. Vehicle_Age')
plt.xlabel('Mileage')
plt.ylabel('Age of Vehicle')
plt.show()

# %%
# Calculate average mileage for each brand within each fuel type
avg_mileage = df3.groupby(['ft', 'model'])['Mileage'].mean().reset_index()

# Sort and select the top 3 brands for each fuel type
top_brands_per_fuel = avg_mileage.groupby('ft').apply(lambda x: x.nlargest(1, 'Mileage')).reset_index(drop=True)

plt.figure(figsize=(16, 10))
sns.stripplot(x='Mileage', y='model', hue='ft', data=top_brands_per_fuel, palette='rocket', dodge=True,size=10)
plt.title('Mileage for Top Brand by Fuel Type')
plt.xlabel('Mileage')
plt.ylabel('Brand')
plt.legend(title='Fuel Type')
plt.show()
# Out:
# C:\Users\Dharshinee R\AppData\Local\Temp\ipykernel_23412\2778772454.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_brands_per_fuel = avg_mileage.groupby('ft').apply(lambda x: x.nlargest(1, 'Mileage')).reset_index(drop=True)

# %% [markdown]
# Feature Selection-Categorical Variables

# %% [markdown]
# 'city', 'ft', 'bt', 'oem', 'transmission', 'Insurance Validity',
#        'Ownership', 'Color', 'model'],

# %%
from scipy.stats import f_oneway



group1 = df3.groupby('city')['price'].apply(list)
F1, p1 = f_oneway(*group1)
print(f"Feature1 - ANOVA F-statistic: {F1}, p-value: {p1}")

# Perform ANOVA for Feature2
group2 = df3.groupby('ft')['price'].apply(list)
F2, p2 = f_oneway(*group2)
print(f"Feature2 - ANOVA F-statistic: {F2}, p-value: {p2}")

group3 = df3.groupby('bt')['price'].apply(list)
F3, p3 = f_oneway(*group3)
print(f"Feature3 - ANOVA F-statistic: {F3}, p-value: {p3}")

# Perform ANOVA for Feature2
group4 = df3.groupby('oem')['price'].apply(list)
F4, p4 = f_oneway(*group4)
print(f"Feature4 - ANOVA F-statistic: {F4}, p-value: {p4}")

group5 = df3.groupby('transmission')['price'].apply(list)
F5, p5 = f_oneway(*group5)
print(f"Feature5 - ANOVA F-statistic: {F5}, p-value: {p5}")

# Perform ANOVA for Feature2
group6 = df3.groupby('Insurance Validity')['price'].apply(list)
F6, p6 = f_oneway(*group6)
print(f"Feature6 - ANOVA F-statistic: {F6}, p-value: {p6}")

group7 = df3.groupby('Ownership')['price'].apply(list)
F7, p7 = f_oneway(*group7)
print(f"Feature7 - ANOVA F-statistic: {F7}, p-value: {p7}")

# Perform ANOVA for Feature2
group8 = df3.groupby('Color')['price'].apply(list)
F8, p8 = f_oneway(*group8)
print(f"Feature8 - ANOVA F-statistic: {F8}, p-value: {p8}")

group9 = df3.groupby('model')['price'].apply(list)
F9, p9 = f_oneway(*group9)
print(f"Feature9 - ANOVA F-statistic: {F9}, p-value: {p9}")


# Select features with significant p-values
selected_features = []
if p1 < 0.05:
    selected_features.append('Feature1')
if p2 < 0.05:
    selected_features.append('Feature2')
if p3 < 0.05:
    selected_features.append('Feature3')
if p4 < 0.05:
    selected_features.append('Feature4')
if p5 < 0.05:
    selected_features.append('Feature5')
if p6 < 0.05:
    selected_features.append('Feature6')
if p7 < 0.05:
    selected_features.append('Feature7')
if p8 < 0.05:
    selected_features.append('Feature8')
if p9 < 0.05:
    selected_features.append('Feature9')

print(f"Selected Features: {selected_features}")
# Out:
# Feature1 - ANOVA F-statistic: 30.54774108457853, p-value: 7.95371178757223e-31
# Feature2 - ANOVA F-statistic: 8.18072840780931, p-value: 1.9648968412938628e-05
# Feature3 - ANOVA F-statistic: 511.33450985757725, p-value: 0.0
# Feature4 - ANOVA F-statistic: 149.59093973278019, p-value: 0.0
# Feature5 - ANOVA F-statistic: 1186.7716830043398, p-value: 1.364853052579733e-239
# Feature6 - ANOVA F-statistic: 14.421765833226504, p-value: 2.046638107376571e-16
# Feature7 - ANOVA F-statistic: 103.15770715574371, p-value: 3.544659595628617e-105
# Feature8 - ANOVA F-statistic: 3.8134439093688, p-value: 5.304466388617828e-42
# Feature9 - ANOVA F-statistic: 97.82541763202359, p-value: 0.0
# Selected Features: ['Feature1', 'Feature2', 'Feature3', 'Feature4', 'Feature5', 'Feature6', 'Feature7', 'Feature8', 'Feature9']

# %%
from scipy.stats import chi2_contingency

def chi_square_test(data, target):
    results = []
    for column in data.columns:
        if data[column].dtype == 'object':
            contingency_table = pd.crosstab(data[column], target)
            chi2, p, dof, expected  = chi2_contingency(contingency_table)
            results.append((column, p))
    return [col for col, p in results if p < 0.05]

selected_columns = chi_square_test(df3.drop('price', axis=1), df3['price'])
print(selected_columns)
# Out:
# ['city', 'ft', 'bt', 'oem', 'transmission', 'Insurance Validity', 'Ownership', 'model']

# %%
corr_matrix = df3[['km', 'modelYear', 'Engine Displacement', 'Mileage', 'price', 'Seating Capacity', 'Vehicle_Age']].corr()

# Set the figure size
plt.figure(figsize=(10, 8))

# Create a heatmap with annotations and a coolwarm color palette
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlations')
plt.show()

# %% [markdown]
# Based on the heatmap ,the selected features with (Engine displacement,Mileage,Vehicle Age)

# %%
plt.boxplot(df3['Engine Displacement'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f1ba91f110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f1ba91f390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f1ba91efd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f1ba91f610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f1ba91f750>],
#  'means': []}

# %%
Q1= np.percentile(df3['Engine Displacement'],25)
Q3= np.percentile(df3['Engine Displacement'],75)
IQR= Q3 -Q1
upper = df3['Engine Displacement']>=(Q3+1.5*IQR)
print("upper bound:",upper)
upper_outliers=np.where(upper)

lower=df3['Engine Displacement']<=(Q1-1.5*IQR)
print("Lower bound:", lower)
lower_outliers=np.where(lower)
# Out:
# upper bound: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8356    False
# 8357    False
# 8358    False
# 8359    False
# 8360    False
# Name: Engine Displacement, Length: 8361, dtype: bool
# Lower bound: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8356    False
# 8357    False
# 8358    False
# 8359    False
# 8360    False
# Name: Engine Displacement, Length: 8361, dtype: bool

# %%
for each in upper_outliers:
 df3['Engine Displacement']=df3['Engine Displacement'].drop(each)
for each in lower_outliers:
 df3['Engine Displacement']=df3['Engine Displacement'].drop(each)

# %%
plt.boxplot(df3['Mileage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f1ba95aad0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f1ba95ad50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f1ba95a990>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f1ba95afd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f1ba95b110>],
#  'means': []}

# %%
Q1= np.percentile(df3['Mileage'],25)
Q3= np.percentile(df3['Mileage'],75)
IQR= Q3 -Q1
upper = df3['Mileage']>=(Q3+1.5*IQR)
print("upper bound:",upper)
upper_outliers=np.where(upper)

lower=df3['Mileage']<=(Q1-1.5*IQR)
print("Lower bound:", lower)
lower_outliers=np.where(lower)
# Out:
# upper bound: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8356    False
# 8357    False
# 8358    False
# 8359    False
# 8360    False
# Name: Mileage, Length: 8361, dtype: bool
# Lower bound: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8356    False
# 8357    False
# 8358    False
# 8359    False
# 8360    False
# Name: Mileage, Length: 8361, dtype: bool

# %%
for each in upper_outliers:
 df3['Mileage']=df3['Mileage'].drop(each)
for each in lower_outliers:
 df3['Mileage']=df3['Mileage'].drop(each)

# %%
plt.boxplot(df3['Vehicle_Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f1bace2d50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f1bace2fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f1bace2c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f1bace3250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f1bace3390>],
#  'means': []}

# %%
Q1= np.percentile(df3['Vehicle_Age'],25)
Q3= np.percentile(df3['Vehicle_Age'],75)
IQR= Q3 -Q1
upper = df3['Vehicle_Age']>=(Q3+1.5*IQR)
print("upper bound:",upper)
upper_outliers=np.where(upper)

lower=df3['Vehicle_Age']<=(Q1-1.5*IQR)
print("Lower bound:", lower)
lower_outliers=np.where(lower)
# Out:
# upper bound: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8356    False
# 8357    False
# 8358    False
# 8359    False
# 8360    False
# Name: Vehicle_Age, Length: 8361, dtype: bool
# Lower bound: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8356    False
# 8357    False
# 8358    False
# 8359    False
# 8360    False
# Name: Vehicle_Age, Length: 8361, dtype: bool

# %%
for each in upper_outliers:
 df3['Vehicle_Age']=df3['Vehicle_Age'].drop(each)
for each in lower_outliers:
 df3['Vehicle_Age']=df3['Vehicle_Age'].drop(each)

# %%
df3.dropna(subset=['Engine Displacement'], inplace=True)
df3.dropna(subset=['Vehicle_Age'], inplace=True)
df3.dropna(subset=['Mileage'], inplace=True)

# %%
df3
# Out:
#          city      ft         bt            oem transmission  \
# 0     Chennai  Petrol        SUV            Kia    Automatic
# 1     Chennai  Petrol   Minivans         Maruti       Manual
# 2     Chennai  Petrol        SUV         Nissan       Manual
# 3     Chennai  Petrol  Hatchback        Hyundai       Manual
# 4     Chennai  Petrol  Hatchback          Honda       Manual
# ...       ...     ...        ...            ...          ...
# 8356  Kolkata  Petrol  Hatchback         Maruti       Manual
# 8357  Kolkata  Petrol  Hatchback         Maruti       Manual
# 8358  Kolkata  Petrol      Sedan  Mercedes-Benz    Automatic
# 8359  Kolkata  Petrol  Hatchback         Maruti       Manual
# 8360  Kolkata  Diesel        SUV        Renault       Manual
#
#          Insurance Validity     Ownership   Color        km  \
# 0     Third Party insurance   First Owner   Black   20000.0
# 1             Comprehensive   First Owner    Grey   20687.0
# ...

# %%
df3.to_excel('Final1.xlsx',index=False)

# %%
fig, boxplot = plt.subplots(figsize = (15,10))
boxplot = sns.boxplot(
    data=df3,
    x='price', 
    y='ft',
    orient='h',
    palette="viridis"
)
# Out:
# C:\Users\Dharshinee R\AppData\Local\Temp\ipykernel_23412\2524279942.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   boxplot = sns.boxplot(

# %%
sns.boxplot(x='price', y='city', data=df3, hue='city', palette='coolwarm', legend=False)

plt.title('Box Plot of Value by City')
plt.xlabel('price')
plt.ylabel('city')
plt.show()

# %%
sns.boxplot(x='price', y='oem', data=df3, hue='oem', palette='coolwarm', legend=False)

plt.title('Box Plot of Value by Category')
plt.xlabel('price')
plt.ylabel('Brand')
plt.show()

# %%
sns.boxplot(x='price', y='Ownership', data=df3, hue='Ownership', palette='coolwarm', legend=False)

plt.title('Box Plot of Value by Category')
plt.xlabel('price')
plt.ylabel('Ownership')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm



# Plot histogram
plt.hist(df3['Engine Displacement'], bins=5, density=True, alpha=0.6, color='g')

# Plot the normal distribution curve
mean, std = df3['Engine Displacement'].mean(), df3['Engine Displacement'].std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)
title = " Engine Displacement-Fit results: mu = %.2f,  std = %.2f" % (mean, std)
plt.title(title)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm



# Plot histogram
plt.hist(df3['Mileage'], bins=5, density=True, alpha=0.6, color='b')

# Plot the normal distribution curve
mean, std = df3['Mileage'].mean(), df3['Mileage'].std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mean, std)
plt.title(title)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm



# Plot histogram
plt.hist(df3['Vehicle_Age'], bins=5, density=True, alpha=0.6, color='r')

# Plot the normal distribution curve
mean, std = df3['Vehicle_Age'].mean(), df3['Vehicle_Age'].std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mean, std)
plt.title(title)

plt.show()
